# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
expenditures = pd.read_csv('Expenditures_2018_to_Current_Year.csv')
vendors = pd.read_csv('Vendor_List.csv')

# %%
#Drop invoice date this column is completely nan
expenditures.drop('invoice_date',axis =1, inplace = True)

# %%
#expenditures['Check_Date']
expenditures['Check_Date'] = pd.to_datetime(expenditures['Check_Date'])
expenditures['Check_Date'] = expenditures['Check_Date'].dt.date
expenditures['Check_Date'] = pd.to_datetime(expenditures['Check_Date'])

# %%
vendors.columns = vendors.columns.str.lower().str.strip()

# %%
vendors.columns.str.strip()
# Out:
# Index(['vendor', 'vendor_id', 'vendor_city', 'vendor_state', 'vendor_zip',
#        'objectid'],
#       dtype='object')

# %%
expenditures.columns = expenditures.columns.str.lower().str.strip()
expenditures.columns
# Out:
# Index(['fiscal_year', 'fiscal_period', 'invoice_status', 'vendor_id',
#        'vendor_name', 'check_number', 'payment_amount', 'check_date',
#        'invoice_number', 'line_item_desc', 'purch_order_no', 'org_code',
#        'org_description', 'object_code', 'object_description', 'payment_type',
#        'payment_status', 'fund_code', 'fund', 'function_code', 'function_',
#        'department_code', 'department', 'division_code', 'division',
#        'payment_id', 'department_no', 'department_description', 'objectid'],
#       dtype='object')

# %%
engine = create_engine("postgresql://postgres:admin@localhost:5432/Naperville Finances")

# %%
vendors.to_sql('vendors', engine, index = False)

# %%
expenditures.to_sql('expenditures', engine, index = False)

# %%
# hostname = 'localhost'
# database = 'Naperville Finances'
# username = 'postgres'
# pwd = 'admin'
# port = 5432

# %%
vendors
# Out:
#                                      VENDOR  VENDOR_ID  \
# 0                           /N SOFTWARE INC      17219
# 1                               114 EVB INC      18946
# 2     191 II NAPERVILLE HOTEL OPERATING LLC      17209
# 3                  1ST CHOICE EQUIPMENT LLC      17963
# 4                        360 YOUTH SERVICES      11308
# ...                                     ...        ...
# 2313                  ZOLL DATA SYSTEMS INC      18606
# 2314                      ZOLL MEDICAL CORP      12425
# 2315                              ZONES LLC        303
# 2316                               ZSRM INC       1372
# 2317        ZURICH TECHNOLOGY SOLUTIONS INC       1094
#
#                    VENDOR_CITY VENDOR_STATE  VENDOR_ZIP  OBJECTID
# 0     CHAPEL HILL                        NC  27517              1
# 1     NAPERVILLE                         IL  60540              2
# 2     RIVERWOODS                         IL  60015              3
# ...

# %%
expenditures
# Out:
#         Fiscal_Year  Fiscal_Period Invoice_Status  Vendor_ID  \
# 0              2021              5           Paid     999997
# 1              2021              5           Paid     999997
# 2              2021              5           Paid     999997
# 3              2021              5           Paid     999997
# 4              2021              5           Paid     999997
# ...             ...            ...            ...        ...
# 113896         2021              5           Paid     999997
# 113897         2021              5           Paid     999997
# 113898         2021              5           Paid     999997
# 113899         2021              5           Paid     999997
# 113900         2021              5           Paid     999997
#
#                         Vendor_Name  Check_Number  Payment_Amount Check_Date  \
# 0       ONE-TIME PAY-PC CARD VENDOR             0           23.47 2021-05-11
# ...
